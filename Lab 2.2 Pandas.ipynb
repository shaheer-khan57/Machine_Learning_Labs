# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas

# %%
students = {
    'Name': ["Muhammad Ayub ", " Ibraheem khan", "Muhammad Abid", "Shumail Khan","Qasim Ali"],
    'Marks': [80, 72, 77, 65, 15],
    'Class':["1st Year", "2nd Year", "1st Year", "3rd Year", "2nd Year"],
    'Age': [20, 21, 19, 22, 21]
}

# %%
df = pandas.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# ## Saving to CSV and other extensions like excel

# %%
df.to_csv('pythonMonday.csv')

# %% [markdown]
# ## Remove Index and saving the csv file

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
df.head()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Specify No of rows to show

# %%
df.head(3)
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19

# %%
df.tail(3)
# Out:
#             Name  Marks     Class  Age
# 2  Muhammad Abid     77  1st Year   19
# 3   Shumail Khan     65  3rd Year   22
# 4      Qasim Ali     15  2nd Year   21

# %%
df.tail()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   61.800000  20.600000
# std    26.771253   1.140175
# min    15.000000  19.000000
# 25%    65.000000  20.000000
# 50%    72.000000  21.000000
# 75%    77.000000  21.000000
# max    80.000000  22.000000

# %% [markdown]
# # Reading csv or other files

# %%
classData= pd.read_csv("pythonMondayRemoveIndex.csv")
classData
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
classData= pd.read_csv("pythonMonday.csv")
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop('Name', axis=1)
# Out:
#    Unnamed: 0  Marks     Class  Age
# 0           0     80  1st Year   20
# 1           1     72  2nd Year   21
# 2           2     77  1st Year   19
# 3           3     65  3rd Year   22
# 4           4     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop(1, axis=0)
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Check the spelling

# %%
classData['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 classData['class']
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'class'

# %% [markdown]
# # Check the trail space

# %%
classData['Class ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 classData['Class ']
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Class '

# %% [markdown]
# # Corrected Spelling

# %%
classData['Name']
# Out:
# 0    Muhammad Ayub
# 1     Ibraheem khan
# 2     Muhammad Abid
# 3      Shumail Khan
# 4         Qasim Ali
# Name: Name, dtype: object

# %% [markdown]
# # Check the head space

# %%
classData[' Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 classData[' Name']
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: ' Name'

# %%
type(classData)
# Out:
# pandas.core.frame.DataFrame

# %%
type(classData['Name'])
# Out:
# pandas.core.series.Series

# %%
classData['Age']
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# 4    21
# Name: Age, dtype: int64

# %% [markdown]
# classData['gpa'][0]

# %%
classData['Age'][0]
# Out:
# 20

# %%
classData['Age'][0]=90
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_7800\883805414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['Age'][0]=90

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   90
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData['Age'][4]
# Out:
# 21

# %%
classData['Age'][4]=5
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_7800\1411840039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['Age'][4]=5

# %%
classData["Name"][4]

# %% [markdown]
# # Rename the column name

# %%
classData.rename(columns={'Age': 'AGE'})
# Out:
#    Unnamed: 0            Name  Marks     Class  AGE
# 0           0  Muhammad Ayub      80  1st Year   90
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year    5

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
classData
# Out:
#         Unnamed: 0            Name  Marks     Class  Age
# First            0  Muhammad Ayub      80  1st Year   90
# Second           1   Ibraheem khan     72  2nd Year   21
# Third            2   Muhammad Abid     77  1st Year   19
# Fourth           3    Shumail Khan     65  3rd Year   22
# Fifth            4       Qasim Ali     15  2nd Year    5

# %% [markdown]
# # Asignment

# %%
classData.drop('Unnamed: 0', axis=1)
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   90
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
classdata = classData.drop('Unnamed: 0', axis=1)
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   90
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Inplace

# %%
classData.drop('Unnamed: 0', axis=1, inplace = True)
classData
# Out:
#                   Name  Marks     Class  Age
# First   Muhammad Ayub      80  1st Year   90
# Second   Ibraheem khan     72  2nd Year   21
# Third    Muhammad Abid     77  1st Year   19
# Fourth    Shumail Khan     65  3rd Year   22
# Fifth        Qasim Ali     15  2nd Year    5

# %%
classData
# Out:
#                   Name  Marks     Class  Age
# First   Muhammad Ayub      80  1st Year   90
# Second   Ibraheem khan     72  2nd Year   21
# Third    Muhammad Abid     77  1st Year   19
# Fourth    Shumail Khan     65  3rd Year   22
# Fifth        Qasim Ali     15  2nd Year    5

# %% [markdown]
# # Accessing the value in Dataframe

# %%
classData["Name"]
# Out:
# 0    Muhammad Ayub
# 1     Ibraheem khan
# 2     Muhammad Abid
# 3      Shumail Khan
# 4         Qasim Ali
# Name: Name, dtype: object

# %%
classData["Name"]["Fifth"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 classData["Name"]["Fifth"]
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'Fifth'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['Age']

# %%
 type(classData['Age'])

# %%
classData

# %%
type(classData)

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.868069
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.657794
# 1     0.616216
# 2     0.874429
# 3     0.018684
# 4     0.768349
# 5     0.031785
# 6     0.732648
# 7     0.468565
# 8     0.566553
# 9     0.394947
# 10    0.339090
# 11    0.613644
# 12    0.309872
# 13    0.253234
# 14    0.292602
# 15    0.315246
# 16    0.678459
# 17    0.331180
# 18    0.420041
# 19    0.240173
# 20    0.182486
# 21    0.261971
# 22    0.889009
# 23    0.014944
# 24    0.395098
# 25    0.581953
# 26    0.597675
# 27    0.665255
# 28    0.156490
# 29    0.092513
# dtype: float64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
np.random.rand(3,4)
# Out:
# array([[9.47156456e-01, 6.06351093e-02, 9.00726589e-01, 4.46735761e-01],
#        [1.03220692e-01, 2.75932301e-01, 9.97966781e-01, 9.31072003e-04],
#        [6.25862028e-01, 5.05920087e-01, 3.49527452e-01, 7.56105193e-01]])

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.core.frame.DataFrame

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.071659  0.053539  0.577694  0.149656  0.250617
# 1  0.829765  0.702537  0.170021  0.767394  0.409780

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.159392  0.192224  0.256405  0.834375  0.961702
# 329  0.267107  0.184517  0.279769  0.262973  0.145641

# %%
newDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.497238    0.478598    0.533862    0.517721    0.511718
# std      0.300523    0.282894    0.286243    0.291697    0.299361
# min      0.002541    0.000548    0.000812    0.000036    0.000168
# 25%      0.220138    0.244081    0.314676    0.300652    0.243268
# 50%      0.498916    0.456495    0.529615    0.501387    0.529532
# 75%      0.770012    0.705883    0.772190    0.773505    0.777838
# max      0.999672    0.998975    0.999895    0.998422    0.996240

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# # Change the value inside the dataframe

# %%
newDf[0][0]= 10000.0

# %%
newDf
# Out:
#                 0         1         2         3         4
# 0    10000.000000  0.053539  0.577694  0.149656  0.250617
# 1        0.829765  0.702537  0.170021  0.767394  0.409780
# 2        0.752383  0.057536  0.939825  0.958262  0.237424
# 3        0.358952  0.523981  0.966682  0.425873  0.990508
# 4        0.247553  0.554370  0.674384  0.638962  0.738900
# ..            ...       ...       ...       ...       ...
# 325      0.962042  0.799871  0.714804  0.842758  0.856560
# 326      0.927275  0.061766  0.361509  0.482754  0.310909
# 327      0.415293  0.587988  0.860444  0.753959  0.186442
# 328      0.159392  0.192224  0.256405  0.834375  0.961702
# 329      0.267107  0.184517  0.279769  0.262973  0.145641
#
# [330 rows x 5 columns]

# %%
newDf.head()
# Out:
#               0         1         2         3         4
# 0  10000.000000  0.053539  0.577694  0.149656  0.250617
# 1      0.829765  0.702537  0.170021  0.767394  0.409780
# 2      0.752383  0.057536  0.939825  0.958262  0.237424
# 3      0.358952  0.523981  0.966682  0.425873  0.990508
# 4      0.247553  0.554370  0.674384  0.638962  0.738900

# %% [markdown]
# # Transpose

# %%
newDf.T
# Out:
#             0         1         2         3         4         5         6    \
# 0  10000.000000  0.829765  0.752383  0.358952  0.247553  0.902797  0.821940
# 1      0.053539  0.702537  0.057536  0.523981  0.554370  0.663549  0.205853
# 2      0.577694  0.170021  0.939825  0.966682  0.674384  0.761876  0.267703
# 3      0.149656  0.767394  0.958262  0.425873  0.638962  0.898890  0.666840
# 4      0.250617  0.409780  0.237424  0.990508  0.738900  0.860906  0.208216
#
#         7         8         9    ...       320       321       322       323  \
# 0  0.971893  0.241234  0.873172  ...  0.340022  0.913982  0.270708  0.723429
# 1  0.800891  0.845378  0.131997  ...  0.237146  0.566765  0.347083  0.521803
# 2  0.873100  0.666042  0.034248  ...  0.305584  0.559220  0.274160  0.039384
# 3  0.986548  0.374778  0.298191  ...  0.611215  0.700240  0.547524  0.388891
# 4  0.254014  0.166844  0.033347  ...  0.297488  0.041851  0.957761  0.838564
#
#         324       325       326       327       328       329
# 0  0.297802  0.962042  0.927275  0.415293  0.159392  0.267107
# 1  0.185349  0.799871  0.061766  0.587988  0.192224  0.184517
# 2  0.137565  0.714804  0.361509  0.860444  0.256405  0.279769
# 3  0.998422  0.842758  0.482754  0.753959  0.834375  0.262973
# 4  0.679813  0.856560  0.310909  0.186442  0.961702  0.145641
#
# [5 rows x 330 columns]

# %% [markdown]
# # Sorting

# %%
newDf.sort_index(axis=0)
# Out:
#                 0         1         2         3         4
# 0    10000.000000  0.053539  0.577694  0.149656  0.250617
# 1        0.829765  0.702537  0.170021  0.767394  0.409780
# 2        0.752383  0.057536  0.939825  0.958262  0.237424
# 3        0.358952  0.523981  0.966682  0.425873  0.990508
# 4        0.247553  0.554370  0.674384  0.638962  0.738900
# ..            ...       ...       ...       ...       ...
# 325      0.962042  0.799871  0.714804  0.842758  0.856560
# 326      0.927275  0.061766  0.361509  0.482754  0.310909
# 327      0.415293  0.587988  0.860444  0.753959  0.186442
# 328      0.159392  0.192224  0.256405  0.834375  0.961702
# 329      0.267107  0.184517  0.279769  0.262973  0.145641
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=0, ascending=False)
# Out:
#                 0         1         2         3         4
# 329      0.267107  0.184517  0.279769  0.262973  0.145641
# 328      0.159392  0.192224  0.256405  0.834375  0.961702
# 327      0.415293  0.587988  0.860444  0.753959  0.186442
# 326      0.927275  0.061766  0.361509  0.482754  0.310909
# 325      0.962042  0.799871  0.714804  0.842758  0.856560
# ..            ...       ...       ...       ...       ...
# 4        0.247553  0.554370  0.674384  0.638962  0.738900
# 3        0.358952  0.523981  0.966682  0.425873  0.990508
# 2        0.752383  0.057536  0.939825  0.958262  0.237424
# 1        0.829765  0.702537  0.170021  0.767394  0.409780
# 0    10000.000000  0.053539  0.577694  0.149656  0.250617
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=1)
# Out:
#                 0         1         2         3         4
# 0    10000.000000  0.053539  0.577694  0.149656  0.250617
# 1        0.829765  0.702537  0.170021  0.767394  0.409780
# 2        0.752383  0.057536  0.939825  0.958262  0.237424
# 3        0.358952  0.523981  0.966682  0.425873  0.990508
# 4        0.247553  0.554370  0.674384  0.638962  0.738900
# ..            ...       ...       ...       ...       ...
# 325      0.962042  0.799871  0.714804  0.842758  0.856560
# 326      0.927275  0.061766  0.361509  0.482754  0.310909
# 327      0.415293  0.587988  0.860444  0.753959  0.186442
# 328      0.159392  0.192224  0.256405  0.834375  0.961702
# 329      0.267107  0.184517  0.279769  0.262973  0.145641
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=1, ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 newDf.sort_index(axis=1, ascending=False)
#
# NameError: name 'newDf' is not defined

# %%
newDf.head()

# %%
newDf[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 newDf[0][1]
#
# NameError: name 'newDf' is not defined

# %%
type(newDf[0])

# %%
newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 newDf
#
# NameError: name 'newDf' is not defined

# %% [markdown]
# ## view

# %%
newDfView=newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 newDfView=newDf
#
# NameError: name 'newDf' is not defined

# %%
newDfView

# %%
newDfView[0][0]=765
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 newDfView[0][0]=765
#
# NameError: name 'newDfView' is not defined

# %%
newDf.head()

# %%
newDfView.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 newDfView.head()
#
# NameError: name 'newDfView' is not defined

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 newDfCopy[0][0]=656
#
# NameError: name 'newDfCopy' is not defined

# %%
newDf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 newDf.head()
#
# NameError: name 'newDf' is not defined

# %%
newDfCopy.head()

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    "Student": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#    Student  Marks  Age
# 0     Ali     85   20
# 1    Sara     92   21
# 2   Bilal     76   19
# 3    Hina     89   22

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  4 non-null      object
#  1   Marks    4 non-null      int64
#  2   Age      4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes
# None

# %%
print("\nDescribe:\n", df.describe())
# Out:
# Describe:
#             Marks        Age
# count   4.000000   4.000000
# mean   85.500000  20.500000
# std     6.952218   1.290994
# min    76.000000  19.000000
# 25%    82.750000  19.750000
# 50%    87.000000  20.500000
# 75%    89.750000  21.250000
# max    92.000000  22.000000

# %%
# -----------------------------
# 2. SORTING
# -----------------------------
print("\nSorting by Marks (descending):\n", df.sort_values("Marks", ascending=False))
print("\nSorting by Age (ascending):\n", df.sort_values("Age"))
# Out:
# Sorting by Marks (descending):
#    Student  Marks  Age
# 1    Sara     92   21
# 3    Hina     89   22
# 0     Ali     85   20
# 2   Bilal     76   19
#
# Sorting by Age (ascending):
#    Student  Marks  Age
# 2   Bilal     76   19
# 0     Ali     85   20
# 1    Sara     92   21
# 3    Hina     89   22

# %%
# -----------------------------
# 3. TRANSPOSE
# -----------------------------
print("\nTransposed DataFrame:\n", df.T)
# Out:
# Transposed DataFrame:
#             0     1      2     3
# Student  Ali  Sara  Bilal  Hina
# Marks     85    92     76    89
# Age       20    21     19    22

# %% [markdown]
# ## Slicing through loc function

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#      Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row with label 2
print(df.loc[2])
# Out:
# Name     Bilal
# Marks       76
# Age         19
# Name: 2, dtype: object

# %%
# 2. Select specific rows and columns by NAME
print(df.loc[1:2, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 1   Sara     92
# 2  Bilal     76

# %%
df["Marks"] > 85
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Marks, dtype: bool

# %%
# 3. Applying Filter: Conditional selection: students with Marks > 85
print(df.loc[df["Marks"] > 85])
# Out:
#    Name  Marks  Age
# 1  Sara     92   21
# 3  Hina     89   22

# %% [markdown]
# ##  Slicing through iloc

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row at index 0
print(df.iloc[0])
# Out:
# Name     Ali
# Marks     85
# Age       20
# Name: 0, dtype: object

# %%
# 2. Select 2 rows and 2 columns by position
print(df.iloc[0:2, 0:2])
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92

# %%
# 3. Select last row using negative index
print(df.iloc[-1])
# Out:
# Name     Hina
# Marks      89
# Age        22
# Name: 3, dtype: object

# %% [markdown]
# # Dropping the Row

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(0).head()
# Out:
#     Name  Marks  Age
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %% [markdown]
# # Dropping the col

# %%
df.drop(['Age'], axis=1).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(['Age'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index().head()
# Out:
#    index   Name  Marks
# 0      0    Ali     85
# 1      1   Sara     92
# 2      2  Bilal     76
# 3      3   Hina     89

# %%
df.reset_index(drop=True).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company')['Sales'].agg(['mean'])
# Out:
#           mean
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Company').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:2380, in GroupBy.mean.<locals>.<lambda>(x)
#    2377 else:
#    2378     result = self._cython_agg_general(
#    2379         "mean",
# -> 2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\generic.py:11949, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11947 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11949 return self._reduce(
#   11950     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951 )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\series.py:6133, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6129     raise TypeError(
#    6130         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6131         "with non-numeric dtypes."
#    6132     )
# -> 6133 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'CarlSarah' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 df.groupby('Company').mean()
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:2378, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2371     return self._numba_agg_general(
#    2372         grouped_mean,
#    2373         executor.float_dtype_mapping,
#    2374         engine_kwargs,
#    2375         min_periods=0,
#    2376     )
#    2377 else:
# -> 2378     result = self._cython_agg_general(
#    2379         "mean",
#    2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1923 else:
#    1924     return result
# -> 1926 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927 return result
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1878, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1876     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877     # preserve the kind of exception that raised
# -> 1878     raise type(err)(msg) from err
#    1880 if ser.dtype == object:
#    1881     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
by_comp.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 by_comp.std()
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:2567, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    2557     return np.sqrt(
#    2558         self._numba_agg_general(
#    2559             grouped_var,
#    (...)
#    2564         )
#    2565     )
#    2566 else:
# -> 2567     return self._cython_agg_general(
#    2568         "std",
#    2569         alt=lambda x: Series(x).std(ddof=ddof),
#    2570         numeric_only=numeric_only,
#    2571         ddof=ddof,
#    2572     )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:339, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     336     # otherwise we have OHLC
#     337     return res.T
# --> 339 return self._call_cython_op(
#     340     values,
#     341     min_count=min_count,
#     342     ngroups=ngroups,
#     343     comp_ids=comp_ids,
#     344     mask=mask,
#     345     result_mask=result_mask,
#     346     **kwargs,
#     347 )
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:397, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     395 out_shape = self._get_output_shape(ngroups, values)
#     396 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
# --> 397 values = self._get_cython_vals(values)
#     398 out_dtype = self._get_out_dtype(values.dtype)
#     400 result = maybe_fill(np.empty(out_shape, dtype=out_dtype))
#
# File ~\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\groupby\ops.py:229, in WrappedCythonOp._get_cython_vals(self, values)
#     223 how = self.how
#     225 if how in ["median", "std", "sem", "skew"]:
#     226     # median only has a float64 implementation
#     227     # We should only get here with is_numeric, as non-numeric cases
#     228     #  should raise in _get_cython_function
# --> 229     values = ensure_float64(values)
#     231 elif values.dtype.kind in "iu":
#     232     if how in ["var", "mean"] or (
#     233         self.kind == "transform" and self.has_dropped_na
#     234     ):
#     235         # has_dropped_na check need for test_null_group_str_transformer
#     236         # result may still include NaN, so we have to cast
#
# File pandas\_libs\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Sam'

# %%
by_comp.min()

# %%
by_comp.max()

# %%
by_comp.count()

# %%
by_comp.describe()
