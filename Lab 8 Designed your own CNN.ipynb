# %% [markdown]
# # Lab Task:
#
# ####  Model: Build and train a custom CNN with the following structure:
#
# Conv2D(64 filters, (3×3), ReLU) → BatchNormalization → MaxPooling2D(2×2)
#
# Conv2D(128 filters, (3×3), ReLU) → BatchNormalization → MaxPooling2D(2×2)
#
# Conv2D(256 filters, (3×3), ReLU) → Dropout(0.3) → MaxPooling2D(2×2)
#
# Flatten → Dense(256, ReLU) → Dropout(0.5) → Dense(1, Sigmoid)
#
# #### Dataset: Use only two classes:
#
# from the last lab tasks
#
# #### Compile with: binary_crossentropy loss and adam optimizer.
#
# #### Train and evaluate the model.

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns

# %%
checkpoints = r'C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'

# %%
train_dir = r'C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\train'
validation_dir = r'C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\validation'
test_dir = r'C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\test'

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',input_shape=(256, 256, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 13,088,452
# Trainable params: 13,088,452
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(learning_rate=1e-4), metrics=['acc'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(256, 256), batch_size=32,class_mode='categorical')
validation_generator = test_datagen.flow_from_directory(validation_dir,target_size=(256, 256),batch_size=32,class_mode='categorical')
# Out:
# Found 1600 images belonging to 4 classes.
# Found 252 images belonging to 4 classes.

# %%
EpochCheckpoint = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
callbacks = [EpochCheckpoint]

# %%
step_size_train = train_generator.n//train_generator.batch_size

model_history = model.fit(train_generator,
                    validation_data =validation_generator,
                   steps_per_epoch=step_size_train,
                   epochs=50,
                    callbacks=callbacks)
# Out:
# Epoch 1/50
# 50/50 [==============================] - ETA: 0s - loss: 0.8991 - acc: 0.5956
# Epoch 1: val_loss improved from inf to 0.52399, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0001-loss0.52.h5
# 50/50 [==============================] - 125s 2s/step - loss: 0.8991 - acc: 0.5956 - val_loss: 0.5240 - val_acc: 0.7540
# Epoch 2/50
# 50/50 [==============================] - ETA: 0s - loss: 0.5219 - acc: 0.7681
# Epoch 2: val_loss did not improve from 0.52399
# 50/50 [==============================] - 108s 2s/step - loss: 0.5219 - acc: 0.7681 - val_loss: 0.6546 - val_acc: 0.7222
# Epoch 3/50
# 50/50 [==============================] - ETA: 0s - loss: 0.4421 - acc: 0.7944
# Epoch 3: val_loss improved from 0.52399 to 0.39630, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0003-loss0.40.h5
# 50/50 [==============================] - 117s 2s/step - loss: 0.4421 - acc: 0.7944 - val_loss: 0.3963 - val_acc: 0.8175
# Epoch 4/50
# 50/50 [==============================] - ETA: 0s - loss: 0.3632 - acc: 0.8313
# Epoch 4: val_loss improved from 0.39630 to 0.36987, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0004-loss0.37.h5
# 50/50 [==============================] - 116s 2s/step - loss: 0.3632 - acc: 0.8313 - val_loss: 0.3699 - val_acc: 0.8333
# Epoch 5/50
# 50/50 [==============================] - ETA: 0s - loss: 0.3270 - acc: 0.8375
# Epoch 5: val_loss improved from 0.36987 to 0.36428, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0005-loss0.36.h5
# 50/50 [==============================] - 109s 2s/step - loss: 0.3270 - acc: 0.8375 - val_loss: 0.3643 - val_acc: 0.8095
# Epoch 6/50
# 50/50 [==============================] - ETA: 0s - loss: 0.3124 - acc: 0.8650
# Epoch 6: val_loss improved from 0.36428 to 0.32564, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0006-loss0.33.h5
# 50/50 [==============================] - 86s 2s/step - loss: 0.3124 - acc: 0.8650 - val_loss: 0.3256 - val_acc: 0.8492
# Epoch 7/50
# 50/50 [==============================] - ETA: 0s - loss: 0.2564 - acc: 0.8769
# Epoch 7: val_loss did not improve from 0.32564
# 50/50 [==============================] - 109s 2s/step - loss: 0.2564 - acc: 0.8769 - val_loss: 1.2331 - val_acc: 0.6071
# Epoch 8/50
# 50/50 [==============================] - ETA: 0s - loss: 0.2464 - acc: 0.8919
# Epoch 8: val_loss improved from 0.32564 to 0.25687, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0008-loss0.26.h5
# 50/50 [==============================] - 92s 2s/step - loss: 0.2464 - acc: 0.8919 - val_loss: 0.2569 - val_acc: 0.8690
# Epoch 9/50
# 50/50 [==============================] - ETA: 0s - loss: 0.2030 - acc: 0.9144
# Epoch 9: val_loss improved from 0.25687 to 0.23600, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0009-loss0.24.h5
# 50/50 [==============================] - 95s 2s/step - loss: 0.2030 - acc: 0.9144 - val_loss: 0.2360 - val_acc: 0.8810
# Epoch 10/50
# 50/50 [==============================] - ETA: 0s - loss: 0.2066 - acc: 0.9131
# Epoch 10: val_loss did not improve from 0.23600
# 50/50 [==============================] - 99s 2s/step - loss: 0.2066 - acc: 0.9131 - val_loss: 0.2461 - val_acc: 0.8889
# Epoch 11/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1693 - acc: 0.9319
# Epoch 11: val_loss improved from 0.23600 to 0.21267, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0011-loss0.21.h5
# 50/50 [==============================] - 93s 2s/step - loss: 0.1693 - acc: 0.9319 - val_loss: 0.2127 - val_acc: 0.8929
# Epoch 12/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1583 - acc: 0.9425
# Epoch 12: val_loss did not improve from 0.21267
# 50/50 [==============================] - 101s 2s/step - loss: 0.1583 - acc: 0.9425 - val_loss: 0.2275 - val_acc: 0.8889
# Epoch 13/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1566 - acc: 0.9413
# Epoch 13: val_loss did not improve from 0.21267
# 50/50 [==============================] - 97s 2s/step - loss: 0.1566 - acc: 0.9413 - val_loss: 0.2139 - val_acc: 0.8849
# Epoch 14/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1339 - acc: 0.9450
# Epoch 14: val_loss improved from 0.21267 to 0.20233, saving model to C:\\Users\\PMYLS\\Documents\\MachineLearningLaB\\Computervision\E1-cp-0014-loss0.20.h5
# 50/50 [==============================] - 100s 2s/step - loss: 0.1339 - acc: 0.9450 - val_loss: 0.2023 - val_acc: 0.8968
# Epoch 15/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1364 - acc: 0.9494
# Epoch 15: val_loss did not improve from 0.20233
# 50/50 [==============================] - 88s 2s/step - loss: 0.1364 - acc: 0.9494 - val_loss: 0.2922 - val_acc: 0.8810
# Epoch 16/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1136 - acc: 0.9550
# Epoch 16: val_loss did not improve from 0.20233
# 50/50 [==============================] - 85s 2s/step - loss: 0.1136 - acc: 0.9550 - val_loss: 0.2316 - val_acc: 0.8849
# Epoch 17/50
# 50/50 [==============================] - ETA: 0s - loss: 0.1133 - acc: 0.9606
# Epoch 17: val_loss did not improve from 0.20233
# 50/50 [==============================] - 101s 2s/step - loss: 0.1133 - acc: 0.9606 - val_loss: 0.2772 - val_acc: 0.8929
# Epoch 18/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0939 - acc: 0.9656
# Epoch 18: val_loss did not improve from 0.20233
# 50/50 [==============================] - 87s 2s/step - loss: 0.0939 - acc: 0.9656 - val_loss: 0.3080 - val_acc: 0.8929
# Epoch 19/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0780 - acc: 0.9775
# Epoch 19: val_loss did not improve from 0.20233
# 50/50 [==============================] - 96s 2s/step - loss: 0.0780 - acc: 0.9775 - val_loss: 0.2218 - val_acc: 0.9127
# Epoch 20/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0825 - acc: 0.9700
# Epoch 20: val_loss did not improve from 0.20233
# 50/50 [==============================] - 106s 2s/step - loss: 0.0825 - acc: 0.9700 - val_loss: 0.2465 - val_acc: 0.9206
# Epoch 21/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0577 - acc: 0.9837
# Epoch 21: val_loss did not improve from 0.20233
# 50/50 [==============================] - 89s 2s/step - loss: 0.0577 - acc: 0.9837 - val_loss: 0.2672 - val_acc: 0.9206
# Epoch 22/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0689 - acc: 0.9737
# Epoch 22: val_loss did not improve from 0.20233
# 50/50 [==============================] - 100s 2s/step - loss: 0.0689 - acc: 0.9737 - val_loss: 0.2482 - val_acc: 0.9048
# Epoch 23/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0436 - acc: 0.9844
# Epoch 23: val_loss did not improve from 0.20233
# 50/50 [==============================] - 102s 2s/step - loss: 0.0436 - acc: 0.9844 - val_loss: 0.3072 - val_acc: 0.9008
# Epoch 24/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0516 - acc: 0.9831
# Epoch 24: val_loss did not improve from 0.20233
# 50/50 [==============================] - 106s 2s/step - loss: 0.0516 - acc: 0.9831 - val_loss: 0.2629 - val_acc: 0.9087
# Epoch 25/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0302 - acc: 0.9894
# Epoch 25: val_loss did not improve from 0.20233
# 50/50 [==============================] - 104s 2s/step - loss: 0.0302 - acc: 0.9894 - val_loss: 0.2633 - val_acc: 0.9048
# Epoch 26/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0704 - acc: 0.9831
# Epoch 26: val_loss did not improve from 0.20233
# 50/50 [==============================] - 110s 2s/step - loss: 0.0704 - acc: 0.9831 - val_loss: 0.2915 - val_acc: 0.8968
# Epoch 27/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0252 - acc: 0.9931
# Epoch 27: val_loss did not improve from 0.20233
# 50/50 [==============================] - 102s 2s/step - loss: 0.0252 - acc: 0.9931 - val_loss: 0.3843 - val_acc: 0.9087
# Epoch 28/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0308 - acc: 0.9900
# Epoch 28: val_loss did not improve from 0.20233
# 50/50 [==============================] - 110s 2s/step - loss: 0.0308 - acc: 0.9900 - val_loss: 0.2922 - val_acc: 0.9167
# Epoch 29/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0172 - acc: 0.9969
# Epoch 29: val_loss did not improve from 0.20233
# 50/50 [==============================] - 110s 2s/step - loss: 0.0172 - acc: 0.9969 - val_loss: 0.3798 - val_acc: 0.9087
# Epoch 30/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0381 - acc: 0.9869
# Epoch 30: val_loss did not improve from 0.20233
# 50/50 [==============================] - 112s 2s/step - loss: 0.0381 - acc: 0.9869 - val_loss: 0.3555 - val_acc: 0.8968
# Epoch 31/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0197 - acc: 0.9956
# Epoch 31: val_loss did not improve from 0.20233
# 50/50 [==============================] - 113s 2s/step - loss: 0.0197 - acc: 0.9956 - val_loss: 0.3741 - val_acc: 0.9008
# Epoch 32/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0173 - acc: 0.9937
# Epoch 32: val_loss did not improve from 0.20233
# 50/50 [==============================] - 112s 2s/step - loss: 0.0173 - acc: 0.9937 - val_loss: 0.4012 - val_acc: 0.9048
# Epoch 33/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0133 - acc: 0.9950
# Epoch 33: val_loss did not improve from 0.20233
# 50/50 [==============================] - 112s 2s/step - loss: 0.0133 - acc: 0.9950 - val_loss: 0.4069 - val_acc: 0.8968
# Epoch 34/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0098 - acc: 0.9975
# Epoch 34: val_loss did not improve from 0.20233
# 50/50 [==============================] - 119s 2s/step - loss: 0.0098 - acc: 0.9975 - val_loss: 1.9384 - val_acc: 0.8135
# Epoch 35/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0202 - acc: 0.9962
# Epoch 35: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 3s/step - loss: 0.0202 - acc: 0.9962 - val_loss: 0.4709 - val_acc: 0.9127
# Epoch 36/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0257 - acc: 0.9956
# Epoch 36: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 2s/step - loss: 0.0257 - acc: 0.9956 - val_loss: 0.4211 - val_acc: 0.9008
# Epoch 37/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0136 - acc: 0.9944
# Epoch 37: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 2s/step - loss: 0.0136 - acc: 0.9944 - val_loss: 0.4671 - val_acc: 0.8968
# Epoch 38/50
# 50/50 [==============================] - ETA: 0s - loss: 9.8204e-04 - acc: 1.0000
# Epoch 38: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 3s/step - loss: 9.8204e-04 - acc: 1.0000 - val_loss: 0.4458 - val_acc: 0.9048
# Epoch 39/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0195 - acc: 0.9969
# Epoch 39: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 2s/step - loss: 0.0195 - acc: 0.9969 - val_loss: 0.4394 - val_acc: 0.9087
# Epoch 40/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0274 - acc: 0.9931
# Epoch 40: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 2s/step - loss: 0.0274 - acc: 0.9931 - val_loss: 0.4901 - val_acc: 0.9127
# Epoch 41/50
# 50/50 [==============================] - ETA: 0s - loss: 6.5078e-04 - acc: 1.0000
# Epoch 41: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 2s/step - loss: 6.5078e-04 - acc: 1.0000 - val_loss: 0.6475 - val_acc: 0.9127
# Epoch 42/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0107 - acc: 0.9962
# Epoch 42: val_loss did not improve from 0.20233
# 50/50 [==============================] - 124s 2s/step - loss: 0.0107 - acc: 0.9962 - val_loss: 0.5071 - val_acc: 0.9008
# Epoch 43/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0218 - acc: 0.9956
# Epoch 43: val_loss did not improve from 0.20233
# 50/50 [==============================] - 125s 3s/step - loss: 0.0218 - acc: 0.9956 - val_loss: 0.4567 - val_acc: 0.9048
# Epoch 44/50
# 50/50 [==============================] - ETA: 0s - loss: 5.3108e-04 - acc: 1.0000
# Epoch 44: val_loss did not improve from 0.20233
# 50/50 [==============================] - 124s 2s/step - loss: 5.3108e-04 - acc: 1.0000 - val_loss: 0.5073 - val_acc: 0.9206
# Epoch 45/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0192 - acc: 0.9956
# Epoch 45: val_loss did not improve from 0.20233
# 50/50 [==============================] - 126s 3s/step - loss: 0.0192 - acc: 0.9956 - val_loss: 0.5107 - val_acc: 0.8968
# Epoch 46/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0058 - acc: 0.9975
# Epoch 46: val_loss did not improve from 0.20233
# 50/50 [==============================] - 129s 3s/step - loss: 0.0058 - acc: 0.9975 - val_loss: 0.7853 - val_acc: 0.8492
# Epoch 47/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0218 - acc: 0.9937
# Epoch 47: val_loss did not improve from 0.20233
# 50/50 [==============================] - 129s 3s/step - loss: 0.0218 - acc: 0.9937 - val_loss: 0.5043 - val_acc: 0.8968
# Epoch 48/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0110 - acc: 0.9969
# Epoch 48: val_loss did not improve from 0.20233
# 50/50 [==============================] - 126s 3s/step - loss: 0.0110 - acc: 0.9969 - val_loss: 0.5335 - val_acc: 0.9087
# Epoch 49/50
# 50/50 [==============================] - ETA: 0s - loss: 3.0221e-04 - acc: 1.0000
# Epoch 49: val_loss did not improve from 0.20233
# 50/50 [==============================] - 104s 2s/step - loss: 3.0221e-04 - acc: 1.0000 - val_loss: 0.5221 - val_acc: 0.9048
# Epoch 50/50
# 50/50 [==============================] - ETA: 0s - loss: 0.0274 - acc: 0.9944
# Epoch 50: val_loss did not improve from 0.20233
# 50/50 [==============================] - 104s 2s/step - loss: 0.0274 - acc: 0.9944 - val_loss: 0.5006 - val_acc: 0.8968

# %%
model_history.history
# Out:
# {'loss': [0.8991315364837646,
#   0.5218632817268372,
#   0.44210097193717957,
#   0.36315402388572693,
#   0.32702770829200745,
#   0.31236883997917175,
#   0.2563871145248413,
#   0.24639655649662018,
#   0.20295129716396332,
#   0.20659498870372772,
#   0.16926661133766174,
#   0.15833213925361633,
#   0.15656745433807373,
#   0.13391883671283722,
#   0.136449933052063,
#   0.11362958699464798,
#   0.11325452476739883,
#   0.09392812103033066,
#   0.07801154255867004,
#   0.08249180018901825,
#   0.05772138759493828,
#   0.06885979324579239,
#   0.043587084859609604,
#   0.05160747095942497,
#   0.03023015893995762,
#   0.07037549465894699,
#   0.02524753101170063,
#   0.03078349679708481,
#   0.017232036218047142,
#   0.038109734654426575,
#   0.019679319113492966,
#   0.017264872789382935,
#   0.013290523551404476,
#   0.009765658527612686,
#   0.02015559934079647,
#   0.025699110701680183,
#   0.013596908189356327,
#   0.0009820408886298537,
#   0.019481725990772247,
#   0.027429476380348206,
#   0.0006507757352665067,
#   0.010737313888967037,
#   0.021786773577332497,
#   0.0005310780834406614,
#   0.019209029152989388,
#   0.005809179041534662,
#   0.0218488909304142,
#   0.011018658988177776,
#   0.0003022148448508233,
#   0.02738046646118164],
#  'acc': [0.5956249833106995,
#   0.7681249976158142,
#   0.7943750023841858,
#   0.831250011920929,
#   0.8374999761581421,
#   0.8650000095367432,
#   0.8768749833106995,
#   0.8918750286102295,
#   0.9143750071525574,
#   0.9131249785423279,
#   0.9318749904632568,
#   0.9424999952316284,
#   0.9412500262260437,
#   0.9449999928474426,
#   0.9493749737739563,
#   0.9549999833106995,
#   0.9606249928474426,
#   0.965624988079071,
#   0.9775000214576721,
#   0.9700000286102295,
#   0.9837499856948853,
#   0.9737499952316284,
#   0.984375,
#   0.9831249713897705,
#   0.9893749952316284,
#   0.9831249713897705,
#   0.9931250214576721,
#   0.9900000095367432,
#   0.996874988079071,
#   0.9868749976158142,
#   0.9956250190734863,
#   0.9937499761581421,
#   0.9950000047683716,
#   0.9975000023841858,
#   0.9962499737739563,
#   0.9956250190734863,
#   0.9943749904632568,
#   1.0,
#   0.996874988079071,
#   0.9931250214576721,
#   1.0,
#   0.9962499737739563,
#   0.9956250190734863,
#   1.0,
#   0.9956250190734863,
#   0.9975000023841858,
#   0.9937499761581421,
#   0.996874988079071,
#   1.0,
#   0.9943749904632568],
#  'val_loss': [0.5239921808242798,
#   0.6546227335929871,
#   0.3963026702404022,
#   0.36986589431762695,
#   0.3642805814743042,
#   0.3256419003009796,
#   1.233123540878296,
#   0.2568720877170563,
#   0.23599542677402496,
#   0.2461078017950058,
#   0.2126668095588684,
#   0.22746491432189941,
#   0.21394780278205872,
#   0.20233356952667236,
#   0.2922336161136627,
#   0.2316092848777771,
#   0.2772316038608551,
#   0.308005690574646,
#   0.22180643677711487,
#   0.24650780856609344,
#   0.2672007381916046,
#   0.24818919599056244,
#   0.3072129786014557,
#   0.26291534304618835,
#   0.2632552981376648,
#   0.29151198267936707,
#   0.3842632472515106,
#   0.29215970635414124,
#   0.3797864019870758,
#   0.35547590255737305,
#   0.37413832545280457,
#   0.40122535824775696,
#   0.4068973660469055,
#   1.9383846521377563,
#   0.47093209624290466,
#   0.4210716784000397,
#   0.46709001064300537,
#   0.44580888748168945,
#   0.4393548369407654,
#   0.49011826515197754,
#   0.6475003361701965,
#   0.5071466565132141,
#   0.4566919207572937,
#   0.5072809457778931,
#   0.5106921195983887,
#   0.7853214144706726,
#   0.5042955875396729,
#   0.5335233807563782,
#   0.5221461653709412,
#   0.5005806684494019],
#  'val_acc': [0.7539682388305664,
#   0.7222222089767456,
#   0.817460298538208,
#   0.8333333134651184,
#   0.8095238208770752,
#   0.8492063283920288,
#   0.6071428656578064,
#   0.8690476417541504,
#   0.8809523582458496,
#   0.8888888955116272,
#   0.8928571343421936,
#   0.8888888955116272,
#   0.8849206566810608,
#   0.89682537317276,
#   0.8809523582458496,
#   0.8849206566810608,
#   0.8928571343421936,
#   0.8928571343421936,
#   0.9126983880996704,
#   0.920634925365448,
#   0.920634925365448,
#   0.9047619104385376,
#   0.9007936716079712,
#   0.908730149269104,
#   0.9047619104385376,
#   0.89682537317276,
#   0.908730149269104,
#   0.9166666865348816,
#   0.908730149269104,
#   0.89682537317276,
#   0.9007936716079712,
#   0.9047619104385376,
#   0.89682537317276,
#   0.8134920597076416,
#   0.9126983880996704,
#   0.9007936716079712,
#   0.89682537317276,
#   0.9047619104385376,
#   0.908730149269104,
#   0.9126983880996704,
#   0.9126983880996704,
#   0.9007936716079712,
#   0.9047619104385376,
#   0.920634925365448,
#   0.89682537317276,
#   0.8492063283920288,
#   0.89682537317276,
#   0.908730149269104,
#   0.9047619104385376,
#   0.89682537317276]}

# %%
acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
plt.savefig(r'C:\Users\PMYLS\Documents\MachineLearningLaB\Computervision\model_Accuracy.png')

# %%
model.save(r'C:\Users\PMYLS\Documents\MachineLearningLaB\Computervision')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\PMYLS\Documents\MachineLearningLaB\Computervision\assets
# INFO:tensorflow:Assets written to: C:\Users\PMYLS\Documents\MachineLearningLaB\Computervision\assets

# %%
#model = load_model(r'C:\Users\Administrator\Downloads\ML Lab\Computer vision\lab11\model_lab11.h5')
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(256, 256), batch_size=32, shuffle=False, class_mode='categorical')
label=test_generator.labels
preds=model.predict(test_generator)
pred = np.argmax(preds, axis = 1)
cm = confusion_matrix(label, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,  display_labels=['Cercospora', 'common_rust','healthy', 'leaf_blight'])
disp.plot()
plt.show()
#plt.savefig(r'C:\Users\Administrator\Downloads\ML Lab\Computer vision\lab11\confusion_matrics.jpg')
# Out:
# Found 200 images belonging to 4 classes.
# 7/7 [==============================] - 3s 369ms/step

# %%
print(classification_report(label, pred, target_names=['Cercospora', 'common_rust','healthy', 'leaf_blight']))
# Out:
#               precision    recall  f1-score   support
#
#   Cercospora       0.90      0.76      0.83        50
#  common_rust       1.00      1.00      1.00        50
#      healthy       0.98      1.00      0.99        50
#  leaf_blight       0.81      0.92      0.86        50
#
#     accuracy                           0.92       200
#    macro avg       0.92      0.92      0.92       200
# weighted avg       0.92      0.92      0.92       200
