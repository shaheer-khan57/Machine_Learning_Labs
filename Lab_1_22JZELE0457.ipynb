# %% [markdown]
# # Lab 1: Introduction to Machine Learning & Environment Setup
# **University of Engineering and Technology Peshawar, Nowshera Campus**
#
# **Student Name:** Shaheer Khan
# **Registration Number:** 22JZELE0457
#
# ---

# %% [markdown]
# ## Objective
# To set up the Python development environment for Machine Learning, install necessary libraries, configure Jupyter Notebook (in VS Code or standalone), and verify the installation by running basic commands.

# %% [markdown]
# ## 1. Environment Setup

# %% [markdown]
# ### 1.1 Install Anaconda / Python
# Recommended: **Anaconda** (includes Python, Jupyter, and most ML libraries)
#
# - Download Anaconda: https://www.anaconda.com/download
# - Or install Python from: https://www.python.org/downloads/

# %% [markdown]
# ### 1.2 Create Virtual Environment (Recommended)

# %%
# Create virtual environment (run in terminal)
# conda create -n ml_env python=3.10 -y
# conda activate ml_env

# %% [markdown]
# ### 1.3 Install Required Libraries

# %%
# !pip install numpy pandas matplotlib scikit-learn seaborn jupyter

# %% [markdown]
# ## 2. Verify Installation

# %%
import sys
print("Python version:", sys.version)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import __version__ as sklearn_version

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", plt.matplotlib.__version__)
print("Scikit-learn version:", sklearn_version)
# Out:
# Python version: 3.9.18 (main, Sep 11 2023, 13:30:38) [MSC v.1916 64 bit (AMD64)]
# NumPy version: 1.26.3
# Pandas version: 2.1.4
# Matplotlib version: 3.8.0
# Scikit-learn version: 1.5.1

# %% [markdown]
# ## 3. Basic Python & ML Concepts

# %%
# Basic NumPy operations
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Sum: 15

# %%
# Pandas basics
import pandas as pd

data = {'Name': ['Ali', 'Sara', 'Usman'], 'Age': [22, 24, 21], 'Score': [85, 90, 78]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Score
# 0    Ali   22     85
# 1   Sara   24     90
# 2  Usman   21     78

# %%
# Matplotlib visualization
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, 'b-', label='sin(x)')
plt.title('Simple Sine Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. GitHub Setup
# 1. Create account at https://github.com/
# 2. Create a new repository (e.g., `UET-ML-Labs`)
# 3. Make it public/private as needed
# 4. Add a professional `README.md`

# %% [markdown]
# ## 5. Useful Resources
# - Stack Overflow: https://stackoverflow.com/
# - Real Python: https://realpython.com/
# - Andrew Ng ML Course: Coursera
# - StatQuest: https://www.youtube.com/@statquest
